# %% [markdown]
# # ex2_scientific1
#
# ## Nội dung bài
# Hien thị ngau nhiem $N-50$ hinh tron:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[0, 1 \right]$
#
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
# generate randomly the center (x,y ) of circle, color, area
N = 50
x = np.random.rand(N)
y = np. random. rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2 # 0 to 15 point radii
# Out:
# CPU times: total: 0 ns
# Wall time: 5.01 μs

# %%
# Mã kiểm tra dữ liệu
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples {x[:10]}')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples {y[:10]}')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples {colors[:10]}')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples {area[:10]}')
# Out:
# + x: len=50, [0.01, 1.00]: 10 samples [0.01259213 0.99645651 0.55233356 0.94219597 0.49581238 0.15050923
#  0.9201443  0.04847782 0.4776252  0.8678976 ]
# + y: len=50, [0.04, 0.98]: 10 samples [0.90629899 0.27008759 0.80314988 0.32290532 0.31574798 0.11459492
#  0.6968866  0.2804113  0.97480251 0.57544678]
# + colors: len=50, [0.02, 0.95]: 10 samples [0.36830484 0.64686607 0.28735543 0.30499587 0.61188235 0.88730836
#  0.01622844 0.3009821  0.10508679 0.29819006]
# + area: len=50, [0.08, 677.39]: 10 samples [ 62.49238002 324.9342594  263.02191597  80.00982337 625.95246441
#  611.83482786 577.31478633 309.45105459 150.65758409 190.36822379]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ### Kết thúc
